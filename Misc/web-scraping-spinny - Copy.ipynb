# %%
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

import pandas as pd
import numpy as np

# %%
path = 'C:\\Users\\R\\Desktop\\MASAI\\PROJECT\\chromedriver.exe'

# %%
browser = webdriver.Chrome(path)
# Out:
# C:\Users\R\AppData\Local\Temp\ipykernel_2976\217355859.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   browser = webdriver.Chrome(path)

# %%
# link = 'https://www.spinny.com/used-cars-in-delhi-ncr/s/?utm_medium=gads_c_search&utm_source=SPD-Search-Top8-National-Brand-EM-Home&utm_content=586920586020&utm_term=e_spinny&partner_id=Cj0KCQjwj_ajBhCqARIsAA37s0y4wtTE4Ilimt_HSyjbzULeMAy8Or6CCXsG_5USVxSrHmv_LcCxWY8aAh4IEALw_wcB&source=googleads&sub_source=SPD-Search-Top8-National-Brand-EM&gclid=Cj0KCQjwj_ajBhCqARIsAA37s0y4wtTE4Ilimt_HSyjbzULeMAy8Or6CCXsG_5USVxSrHmv_LcCxWY8aAh4IEALw_wcB'
# browser.get(link)

# %%
# link = 'https://www.spinny.com/used-cars-in-bangalore/s/?utm_medium=gads_c_search&utm_source=SPD-Search-Top8-National-Brand-EM-Home&utm_content=586920586020&utm_term=e_spinny&partner_id=Cj0KCQjwj_ajBhCqARIsAA37s0y4wtTE4Ilimt_HSyjbzULeMAy8Or6CCXsG_5USVxSrHmv_LcCxWY8aAh4IEALw_wcB&source=googleads&sub_source=SPD-Search-Top8-National-Brand-EM&gclid=Cj0KCQjwj_ajBhCqARIsAA37s0y4wtTE4Ilimt_HSyjbzULeMAy8Or6CCXsG_5USVxSrHmv_LcCxWY8aAh4IEALw_wcB'
# browser.get(link)

# %%
link = 'https://www.spinny.com/used-cars-in-hyderabad/s/?utm_medium=gads_c_search&utm_source=SPD-Search-Top8-National-Brand-EM-Home&utm_content=586920586020&utm_term=e_spinny&partner_id=Cj0KCQjwj_ajBhCqARIsAA37s0y4wtTE4Ilimt_HSyjbzULeMAy8Or6CCXsG_5USVxSrHmv_LcCxWY8aAh4IEALw_wcB&source=googleads&sub_source=SPD-Search-Top8-National-Brand-EM&gclid=Cj0KCQjwj_ajBhCqARIsAA37s0y4wtTE4Ilimt_HSyjbzULeMAy8Or6CCXsG_5USVxSrHmv_LcCxWY8aAh4IEALw_wcB'
browser.get(link)

# %%
parent = browser.current_window_handle

# %%
cities = ['Noida']

# %%
car_info = []

for city in cities:
    search = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[1]/div/span[2]')
    search.click()
    time.sleep(1)
    
    enter_city = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/input')
    enter_city.send_keys(city)
    try:
        submit = browser.find_element(By.CLASS_NAME, 'styles__otherCityDivWrapper')
    except:
        submit = browser.find_element(By.CLASS_NAME, 'styles__cityText')
    submit.click()
    time.sleep(5)

    for page in range(7):
        view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
        for i in view_button:
            i.click()
            time.sleep(3)
            browser.switch_to.window(browser.window_handles[-1])

            try:
                brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
            except:
                brand_and_model = np.nan
            try:
                km_driven = browser.find_element(By.XPATH,".//div[@class = 'DesktopOverview__itemDisplay DesktopOverview__textLowercase']").text
            except:
                km_drive = np.nan
            try:
                fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
            except:
                fuel_type = np.nan
            try:
                transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
            except:
                transmission = np.nan
            try:
                price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
            except:
                price = np.nan
            try:
                all_spec_1 = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]').text
            except:
                all_spec_1 = np.nan
            try:
                all_spec_2 = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]').text
            except:
                all_spec_2 = np.nan

            time.sleep(1)
            car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type': fuel_type, 'transmission':transmission,'all_spec_1':all_spec_1, 'all_spec_2': all_spec_2, 'price':price}
            car_info.append(car_details)
            df = pd.DataFrame(car_info)
            df.to_csv('ncr.csv')
            browser.close()
            browser.switch_to.window(parent)
        time.sleep(4)
    time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In [256], line 20
#      18 i.click()
#      19 time.sleep(3)
# ---> 20 browser.switch_to.window(browser.window_handles[-1])
#      22 try:
#      23     brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:587, in WebDriver.window_handles(self)
#     578 @property
#     579 def window_handles(self) -> List[str]:
#     580     """Returns the handles of all windows within the current session.
#     581
#     582     :Usage:
#    (...)
#     585             driver.window_handles
#     586     """
# --> 587     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# ...

# %%
df = pd.DataFrame(car_info)
df
# Out:
#                             brand_and_model km_driven      fuel_type  \
# 0       2021 Hyundai Venue SX 1.0 Turbo iMT    12K km       · Petrol
# 1    2021 Skoda Kushaq Ambition 1.0L TSI AT    11K km       · Petrol
# 2   2020 Maruti Suzuki S-Presso VXI Opt CNG    81K km   · Petrol+cng
# 3                  2021 Tata Safari XZ Plus    36K km       · Diesel
# 4                        2022 Honda City ZX    13K km       · Petrol
# ..                                      ...       ...            ...
# 60      2021 Hyundai Venue SX 1.0 Turbo iMT    12K km       · Petrol
# 61   2021 Skoda Kushaq Ambition 1.0L TSI AT    11K km       · Petrol
# 62  2020 Maruti Suzuki S-Presso VXI Opt CNG    81K km   · Petrol+cng
# 63                 2021 Tata Safari XZ Plus    36K km       · Diesel
# 64                       2022 Honda City ZX    13K km       · Petrol
#
#     transmission                                         all_spec_1  \
# 0       · Manual  Mileage (ARAI)\n18 kmpl\nGround clearance\n195...
# ...

# %%
car_info = []

for page in range(26):
    view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
    for i in view_button:
        i.click()
        time.sleep(3)
        browser.switch_to.window(browser.window_handles[-1])

        try:
            brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
        except:
            brand_and_model = np.nan
        try:
            km_driven = browser.find_element(By.XPATH,".//div[@class = 'DesktopOverview__itemDisplay DesktopOverview__textLowercase']").text
        except:
            km_drive = np.nan
        try:
            fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
        except:
            fuel_type = np.nan
        try:
            transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
        except:
            transmission = np.nan
        try:
            price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
        except:
            price = np.nan
        try:
            all_spec_1 = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]').text
        except:
            all_spec_1 = np.nan
        try:
            all_spec_2 = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]').text
        except:
            all_spec_2 = np.nan
            
        time.sleep(1)
        car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type': fuel_type, 'transmission':transmission,'all_spec_1':all_spec_1, 'all_spec_2': all_spec_2, 'price':price}
        car_info.append(car_details)
        df = pd.DataFrame(car_info)
        df.to_csv('ncr.csv')
        browser.close()
        browser.switch_to.window(parent)
    time.sleep(4)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In [154], line 8
#       6 i.click()
#       7 time.sleep(3)
# ----> 8 browser.switch_to.window(browser.window_handles[-1])
#      10 try:
#      11     brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:587, in WebDriver.window_handles(self)
#     578 @property
#     579 def window_handles(self) -> List[str]:
#     580     """Returns the handles of all windows within the current session.
#     581
#     582     :Usage:
#    (...)
#     585             driver.window_handles
#     586     """
# --> 587     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# ...

# %%
df = pd.DataFrame(car_info)
df
# Out:
#                                         brand_and_model km_driven  fuel_type  \
# 0                2021 MG Motors Hector 1.5 Sharp DCT AT    23K km   · Petrol
# 1                      2018 Maruti Suzuki Swift ZDI AMT    62K km   · Diesel
# 2                           2014 Maruti Suzuki Ritz ZXI    48K km   · Petrol
# 3                     2013 Hyundai i10 Sportz AT Petrol    23K km   · Petrol
# 4                 2014 Hyundai Grand i10 Magna 1.1 CRDi    73K km   · Diesel
# ...                                                 ...       ...        ...
# 1113                             2018 Honda Brio S(O)MT    47K km   · Petrol
# 1114                             2020 Kia Sonet HTX 1.5    29K km   · Diesel
# 1115                2021 Skoda Kushaq Style 1.5L TSI MT    24K km   · Petrol
# 1116    2022 Skoda Kushaq Style 1.0L TSI AT (6 Airbags)    21K km   · Petrol
# 1117  2021 Hyundai Alcazar Platinum (O) 6 STR 2.0 Pe...    31K km   · Petrol
#
# ...

# %%
df.isnull().sum()
# Out:
# brand_and_model        0
# km_driven              0
# fuel_type              0
# transmission           0
# all_specifications    67
# price                  0
# dtype: int64

# %%
df.to_csv('ncr_120.csv')

# %%
car_info = []

for page in range(50):
    view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
    for i in view_button:
        i.click()
        time.sleep(3)
        browser.switch_to.window(browser.window_handles[-1])
    
        try:
            brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
        except:
            brand_and_model = np.nan
        try:
            km_driven = browser.find_element(By.XPATH,".//div[@class = 'DesktopOverview__itemDisplay DesktopOverview__textLowercase']").text
        except:
            km_drive = np.nan
        try:
            fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
        except:
            fuel_type = np.nan
        try:
            transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
        except:
            transmission = np.nan
        try:
            no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
        except:
            no_of_owner = np.nan
        try:
            price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
        except:
            price = np.nan

        all_specifications = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[2]/button/span')
        all_specifications.click()
        time.sleep(2)
        
        try:
            ground_clearance = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[2]/div/h4').text
        except:
            ground_clearance = np.nan
        try:
            seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
        except:
            seating_capacity = np.nan
        try:
            boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
        except:
            boot_space = np.nan
        try:
            fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
        except:
            fuel_tank_capacity = np.nan
#         try:
#             wheelbase = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[1]/ul/li[6]/span[2]/strong').text
#         except:
#             wheelbase = np.nan
#         try:
#             alloy_wheels = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[1]/ul/li[16]/span[2]/strong').text
#         except:
#             alloy_wheels = np.nan
#         try:
#             no_of_gears = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[2]/ul/li[3]/span[2]/strong').text
#         except:
#             no_of_gears = np.nan
#         try:
#             displacement = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[2]/ul/li[4]/span[2]/strong').text
#         except:
#             displacement = np.nan
#         try:
#             no_of_cylinders = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[2]/ul/li[5]/span[2]/strong').text
#         except:
#             no_of_cylinders = np.nan
        try:
            max_power = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[7]/div/h4').text
        except:
            max_power = np.nan
#         try:
#             max_torque = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[3]/ul/li[2]/span[2]/strong').text
#         except:
#             max_torque = np.nan
        try:
            mileage = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
        except:
            mileage = np.nan
#         try:
#             top_speed = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[3]/ul/li[4]/span[2]/strong').text
#         except:
#             top_speed = np.nan
#         try:
#             steering_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]/div[4]/ul/li[5]/span[2]/strong').text
#         except:
#             steering_type = np.nan

        car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type': fuel_type, 'transmission':transmission,\
                       'no_of_owner':no_of_owner, 'seating_capacity':seating_capacity, 'mileage':mileage, 'top_speed': top_speed,\
                       'ground_clearance':ground_clearance, 'boot_space':boot_space,\
                       'fuel_tank_capacity':fuel_tank_capacity,'wheelbase':wheelbase,\
                       'no_of_gears': no_of_gears,'displacement':displacement, 'no_of_cylinders': no_of_cylinders,\
                       'max_power': max_power, 'max_torque': max_torque, 'price':price}

        car_info.append(car_details)
        time.sleep(1)
        browser.close()
        browser.switch_to.window(parent)
        time.sleep(1)
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In [142], line 8
#       6 i.click()
#       7 time.sleep(3)
# ----> 8 browser.switch_to.window(browser.window_handles[-1])
#      10 try:
#      11     brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:587, in WebDriver.window_handles(self)
#     578 @property
#     579 def window_handles(self) -> List[str]:
#     580     """Returns the handles of all windows within the current session.
#     581
#     582     :Usage:
#    (...)
#     585             driver.window_handles
#     586     """
# --> 587     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# ...

# %%
car_info = []

for page in range(50):
    view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
    for i in view_button:
        i.click()
        time.sleep(3)
        browser.switch_to.window(browser.window_handles[-1])
    
        try:
            brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
        except:
            brand_and_model = np.nan
        try:
            km_driven = browser.find_element(By.XPATH,".//div[@class = 'DesktopOverview__itemDisplay DesktopOverview__textLowercase']").text
        except:
            km_drive = np.nan
        try:
            fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
        except:
            fuel_type = np.nan
        try:
            transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
        except:
            transmission = np.nan
        try:
            specifications = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]').text
        except:
            np.nan
#         try:
#             no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
#         except:
#             no_of_owner = np.nan
        try:
            price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
        except:
            price = np.nan
#         try:
#             ground_clearance = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[2]/div/h4').text
#         except:
#             ground_clearance = np.nan
#         try:
#             seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
#         except:
#             seating_capacity = np.nan
#         try:
#             boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
#         except:
#             boot_space = np.nan
#         try:
#             fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
#         except:
#             fuel_tank_capacity = np.nan
#         try:
#             max_power = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[7]/div/h4').text
#         except:
#             max_power = np.nan
#         try:
#             mileage = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
#         except:
#             mileage = np.nan

        car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type': fuel_type, 'transmission':transmission, 'specifications': specifications, 'price':price}

        car_info.append(car_details)
        time.sleep(1)
        browser.close()
        browser.switch_to.window(parent)
        time.sleep(1)
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In [18], line 8
#       6 i.click()
#       7 time.sleep(3)
# ----> 8 browser.switch_to.window(browser.window_handles[-1])
#      10 try:
#      11     brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\selenium\webdriver\remote\webdriver.py:587, in WebDriver.window_handles(self)
#     578 @property
#     579 def window_handles(self) -> List[str]:
#     580     """Returns the handles of all windows within the current session.
#     581
#     582     :Usage:
#    (...)
#     585             driver.window_handles
#     586     """
# --> 587     return self.execute(Command.W3C_GET_WINDOW_HANDLES)["value"]
#
# ...

# %%
df = pd.DataFrame(car_info)
df
# Out:
#                         brand_and_model km_driven  fuel_type  transmission  \
# 0            2018 Mahindra XUV500 W9 AT    67K km   · Diesel   · Automatic
# 1                  2012 Honda Brio V AT    87K km   · Petrol   · Automatic
# 2                     2014 Honda City V    62K km   · Petrol      · Manual
# 3  2019 Maruti Suzuki Vitara Brezza ZDi    30K km   · Diesel      · Manual
#
#                                       specifications        price
# 0  Mileage (ARAI)\n15.1 kmpl\nGround clearance\n2...  ₹11.69 Lakh
# 1  Mileage (ARAI)\n15.1 kmpl\nGround clearance\n2...   ₹3.19 Lakh
# 2  Mileage (ARAI)\n15.1 kmpl\nGround clearance\n2...   ₹5.24 Lakh
# 3  Mileage (ARAI)\n24.3 kmpl\nGround clearance\n1...   ₹9.71 Lakh

# %%
df.iloc[0,4]
# Out:
# 'Mileage (ARAI)\n15.1 kmpl\nGround clearance\n200 mm\nSeating capacity\n7 units\nFuel tank capacity\n70 litres\nDisplacement\n2179 cc\nVIEW ALL SPECIFICATIONS'

# %%
df.shape

# %%
df.to_csv("cars_ahmedabad_31.csv")

# %%
df = pd.DataFrame(car_info)
df

# %%
# car_info = []

# for page in range(2):
#     view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
#     for i in view_button:
#         i.click()
#         time.sleep(3)
#         browser.switch_to.window(browser.window_handles[-1])
    
#         try:
#             brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#         except:
#             brand_and_model = np.nan
#         try:
#             km_driven = browser.find_element(By.XPATH,".//div[@class = 'DesktopOverview__itemDisplay DesktopOverview__textLowercase']").text
#         except:
#             km_drive = np.nan
#         try:
#             fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
#         except:
#             fuel_type = np.nan
#         try:
#             transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
#         except:
#             transmission = np.nan
#         try:
#             seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
#         except:
#             seating_capacity = np.nan
#         try:
#             mileage = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
#         except:
#             mileage = np.nan
#         try:
#             boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
#         except:
#             boot_space = np.nan
#         try:
#             fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
#         except:
#             fuel_tank_capacity = np.nan
#         try:
#             no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
#         except:
#             no_of_owner = np.nan
#         try:
#             price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
#         except:
#             price = np.nan
        

#         car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type': fuel_type, 'transmission':transmission,\
#                       'seating_capacity':seating_capacity,'mileage':mileage,'boot_space':boot_space,\
#                       'fuel_tank_capacity':fuel_tank_capacity,'no_of_owner':no_of_owner,'price':price}

#         car_info.append(car_details)
#         browser.close()
#         browser.switch_to.window(parent)
#     time.sleep(5)

# %%
cities = ['Delhi NCR','Bangalore','Hyderabad','Mumbai','Pune','Ahmedabad','Chennai','Kolkata',
          'Lucknow','Jaipur','Chandigarh','Coimbatore','Indore','Kochi']

# %%
car_info = []

for city in cities:
    search = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[1]/div/span[2]')
    search.click()
    time.sleep(1)
    
    enter_city = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/input')
    enter_city.send_keys(city)
    submit = browser.find_element(By.CLASS_NAME, 'styles__cityText')
    submit.click()
    time.sleep(2)

    for page in range(5):
        view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
        for i in view_button:
            i.click()
            time.sleep(3)
            browser.switch_to.window(browser.window_handles[-1])

            try:
                brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
            except:
                brand_and_model = np.nan
            try:
                km_driven = browser.find_element(By.XPATH,".//div[@class = 'DesktopOverview__itemDisplay DesktopOverview__textLowercase']").text
            except:
                km_drive = np.nan
            try:
                fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
            except:
                fuel_type = np.nan
            try:
                transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
            except:
                transmission = np.nan
            try:
                price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
            except:
                price = np.nan
            
            # now entering all specifications button
            
            specifications_button = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[4]/section[4]/div/div[2]/div[2]/button/span')
            specifications_button.click()
            time.sleep(2)
            
            try:
                all_specifications = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[1]/div[4]/div[2]/div/div[1]/section[2]').text
            except:
                all_specifications = np.nan
            
            
            car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type': fuel_type, 'transmission':transmission,'all_specifications':all_specifications,'price':price}

            car_info.append(car_details)
            browser.close()
            browser.switch_to.window(parent)
        time.sleep(5)
    time.sleep(5)

# %%
# df = pd.DataFrame(car_info)
# df

# %%
# car_info = []

# for page in range(1):
#     view_button = browser.find_elements(By.XPATH, '//*[@id="listingDesktop"]/div[2]/div/div[2]/div[4]/div[35]/div/div[1]/a/div[1]/h3/p')
#     for i in view_button:
#         i.click()
#         time.sleep(3)
#         browser.switch_to.window(browser.window_handles[-1])
    
#         try:
#             brand_and_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#         except:
#             brand_and_model = np.nan
#         try:
#             km_driven = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[1]').text
#         except:
#             km_driven = np.nan
#         try:
#             fuel_type = browser.find_element(By.CLASS_NAME, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[2]').text
#         except:
#             fuel_type = np.nan
#         try:
#             transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[3]').text
#         except:
#             transmission = np.nan
#         try:
#             seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
#         except:
#             seating_capacity = np.nan
#         try:
#             mileage = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
#         except:
#             mileage = np.nan
#         try:
#             ground_clearance = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[2]/div/h4').text
#         except:
#             ground_clearance = np.nan
#         try:
#             boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
#         except:
#             boot_space = np.nan
#         try:
#             fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
#         except:
#             fuel_tank_capacity = np.nan
#         try:
#             max_power = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[7]/div/h4').text
#         except:
#             max_power = np.nan
#         try:
#             no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
#         except:
#             no_of_owner = np.nan
#         try:
#             insurance_validity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[7]/div[2]').text
#         except:
#             insurance_validity = np.nan
#         try:
#             insurance_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[8]/div[2]').text
#         except:
#             insurance_type = np.nan
#         try:
#             price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
#         except:
#             price = np.nan

#         car_details = {'brand_and_model':brand_and_model, 'km_driven':km_driven, 'fuel_type':fuel_type, 'transmission':transmission,
#                            'seating_capacity':seating_capacity, 'mileage':mileage, 'ground_clearance':ground_clearance, 'boot_space':boot_space,
#                            'fuel_tank_capacity':fuel_tank_capacity, 'max_power':max_power, 'no_of_owner':no_of_owner,
#                            'insurance_validity':insurance_validity,'insurance_type':insurance_type, 'price':price}

#         car_info.append(car_details)
#         browser.close()
#         browser.switch_to.window(parent)
#     time.sleep(5)

# %%
# cities = ['Delhi NCR','Bangalore','Hyderabad','Mumbai','Pune','Ahmedabad','Chennai','Kolkata',
#           'Lucknow','Jaipur','Chandigarh','Coimbatore','Indore','Kochi']

# %%
# car_info = []

# for city in cities:
#     search = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[1]/div/span[2]')
#     search.click()
#     time.sleep(1)
    
#     enter_city = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/input')
#     enter_city.send_keys(city)
#     submit = browser.find_element(By.CLASS_NAME, 'styles__cityText')
#     submit.click()
#     time.sleep(2)
    
#     for page in range(1):
#         view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
#         for i in view_button:
#             i.click()
#             time.sleep(3)
#             browser.switch_to.window(browser.window_handles[-1])

#             try:
#                 brand = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#             except:
#                 pass
#             try:
#                 km_driven = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[1]').text
#             except:
#                 pass
#             try:
#                 fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[3]/div[2]').text
#             except:
#                 pass
#             try:
#                 transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[5]/div[2]').text
#             except:
#                 pass
#             try:
#                 agency_location = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[4]/div/span[1]').text
#             except:
#                 pass
#             try:
#                 price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
#             except:
#                 pass
#             try:
#                 no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
#             except:
#                 pass
#             try:
#                 insurance_validity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[7]/div[2]').text
#             except:
#                 pass
#             try:
#                 insurance_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[8]/div[2]').text
#             except:
#                 pass
#             try:
#                 mileage(ARAI) = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
#             except:
#                 pass
#             try:
#                 ground_clearance = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[2]/div/h4').text
#             except:
#                 pass
#             try:
#                 boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
#             except:
#                 pass
#             try:
#                 seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
#             except:
#                 pass
#             try:
#                 fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
#             except:
#                 pass
#             try:
#                 max_power = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[7]/div/h4').text
#             except:
#                 pass

#             car_details = {'city':city,'basic_info':basic_info, 'distance_ran':distance_ran, 'fuel_type':fuel_type, 'auto_manual': auto_manual}

#             car_info.append(car_details)
#             browser.close()
#             browser.switch_to.window(parent)
#         time.sleep(5)

# %%
# car_info = []

# for city in cities:
#     search = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[1]/div/span[2]')
#     search.click()
#     time.sleep(1)
    
#     enter_city = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/input')
#     enter_city.send_keys(city)
#     submit = browser.find_element(By.CLASS_NAME, 'styles__cityText')
#     submit.click()
#     time.sleep(2)
    
#     for page in range(1):
#         view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
#         for i in view_button:
#             i.click()
#             time.sleep(3)
#             browser.switch_to.window(browser.window_handles[-1])

            
#                 brand_&_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#                 km_driven = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[1]').text
#                 fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[3]/div[2]').text
#                 transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[5]/div[2]').text
#                 agency_location = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[4]/div/span[1]').text
#                 no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
#                 insurance_validity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[7]/div[2]').text
#                 insurance_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[8]/div[2]').text
#                 mileage(ARAI) = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
#                 ground_clearance = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[2]/div/h4').text
#                 boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
#                 seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
#                 fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
#                 max_power = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[7]/div/h4').text
#                 price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
            
#             car_details = {'city':city,'brand_&_model':brand_&_model, 'km_driven':km_driven, 'fuel_type':fuel_type, 'transmission': transmission, 'agency_location':agency_location,
#                           'no_of_owner':no_of_owner, 'insurance_validity':insurance_validity,'insurance_type':insurance_type,'mileage(ARAI)':mileage(ARAI),
#                           'ground_clearance':ground_clearance, 'boot_space':boot_space, 'seating_capacity':seating_capacity, 'fuel_tank_capacity':fuel_tank_capacity,
#                            'max_power':max_power,'price':price}

#             car_info.append(car_details)
#             browser.close()
#             browser.switch_to.window(parent)
#         time.sleep(3)

# %%
# car_info = []

# for city in cities:
#     search = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[1]/div/span[2]')
#     search.click()
#     time.sleep(1)
    
#     enter_city = browser.find_element(By.XPATH, '//*[@id="webMainHead"]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/input')
#     enter_city.send_keys(city)
#     submit = browser.find_element(By.CLASS_NAME, 'styles__cityText')
#     submit.click()
#     time.sleep(2)
    
#     for page in range(1):
#         view_button = browser.find_elements(By.CLASS_NAME, 'CarListingDesktop__carListingCarWrapper')
#         for i in view_button:
#             i.click()
#             time.sleep(3)
#             browser.switch_to.window(browser.window_handles[-1])

            
#             brand_&_model = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/h1').text
#             km_driven = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[2]/span[1]').text
#             fuel_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[3]/div[2]').text
#             transmission = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[5]/div[2]').text
#             agency_location = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[4]/div/span[1]').text
#             no_of_owner = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[6]/div[2]').text
#             insurance_validity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[7]/div[2]').text
#             insurance_type = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[1]/div[2]/div[1]/div/div[8]/div[2]').text
#             mileage(ARAI) = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[1]/div/h4').text
#             ground_clearance = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[2]/div/h4').text
#             boot_space = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[3]/div/h4').text
#             seating_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[5]/div/h4').text
#             fuel_tank_capacity = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[6]/div/h4').text
#             max_power = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[1]/div[3]/section[4]/div/div[2]/div[1]/div[7]/div/h4').text
#             price = browser.find_element(By.XPATH, '//*[@id="react-view"]/div[1]/div/div[2]/div[1]/div[2]/div[2]/div/div[1]/div[1]/div[5]/div[1]/span').text
            
#             car_details = {'city':city,'brand_&_model':brand_&_model, 'km_driven':km_driven, 'fuel_type':fuel_type, 'transmission': transmission, 'agency_location':agency_location,
#                           'no_of_owner':no_of_owner, 'insurance_validity':insurance_validity,'insurance_type':insurance_type,'mileage(ARAI)':mileage(ARAI),
#                           'ground_clearance':ground_clearance, 'boot_space':boot_space, 'seating_capacity':seating_capacity, 'fuel_tank_capacity':fuel_tank_capacity,
#                            'max_power':max_power,'price':price}

#             car_info.append(car_details)
#             browser.close()
#             browser.switch_to.window(parent)
#         time.sleep(3)
